# %% [markdown]
# # Example usage
#
# To use `ivxj` in a project:

# %%
import ivxj

print(ivxj.__version__)
# Out:
# 0.1.0

# %%
import numpy as np
import pandas as pd

# %%
def test_ivxj():
    """Test ivxj function using the paper data"""
    for h in range(1,4):
        for i in range(1,5):
            # get test data
            y = np.loadtxt(f'y_h{h}_i{i}.csv', dtype=np.float64, delimiter=',')
            dX = np.loadtxt(f'dX_h{h}_i{i}.csv', dtype=np.float64, delimiter=',')
            rhoz = np.loadtxt(f'rhoz_h{h}_i{i}.csv', dtype=np.float64, delimiter=',')
            Tlens = np.loadtxt(f'Tlens_h{h}_i{i}.csv', delimiter=',').astype(int)
            X = np.loadtxt(f'X_h{h}_i{i}.csv', dtype=np.float64, delimiter=',')
            expected_result = np.loadtxt(f'result_h{h}_i{i}.csv', dtype=np.float64, delimiter=',')

            r1, r2, r3, r4 = ivxj(y, dX, rhoz, Tlens)
            r5, r6, r7, r8 = ivxj(y, X, rhoz, Tlens)

            actual_result = np.array([r1, r2, r3, r4, r5, r6, r7, r8], dtype= np.float64)

            gap = np.abs(actual_result - expected_result)
            relative_gap = np.abs((actual_result - expected_result)/expected_result)

            print(f"Result for h={h}, i={i}")
            print("-------------------\n")
            result = np.column_stack((actual_result, expected_result, gap, relative_gap))
            df = pd.DataFrame(result, columns=["Actual", "Expected", "Error", "Relative Error"])
            print(df)
            max_value = df["Relative Error"].max()
            mean_value = df["Relative Error"].mean()
            print("\nMaximun value in Relative Error:", max_value)
            print("Mean value in Relative Error:", mean_value,"\n")

# %%
from ivxj.ivxj import ivxj

# %%
test_ivxj()
# Out:
# Result for h=1, i=1
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.002965  0.002965  3.987679e-08        0.000013
# 1  0.003059  0.003059  3.764529e-07        0.000123
# 2  0.000747  0.000747  1.907188e-09        0.000003
# 3  0.850239  0.851170  9.310278e-04        0.001094
# 4  0.002241  0.002570  3.289836e-04        0.128004
# 5  0.002389  0.002938  5.492300e-04        0.186921
# 6  0.000591  0.000516  7.511435e-05        0.145706
# 7  0.914637  1.014600  9.996293e-02        0.098524
#
# Maximun value in Relative Error: 0.18692099480311183
# Mean value in Relative Error: 0.07004857001372108
#
# Result for h=1, i=2
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.000916  0.000916  9.468153e-09        0.000010
# 1  0.000963  0.000963  1.842406e-07        0.000191
# 2  0.000272  0.000272  2.280485e-09        0.000008
# 3  0.813075  0.814020  9.450823e-04        0.001161
# 4  0.000986  0.001065  7.870214e-05        0.073885
# 5  0.001058  0.001379  3.213234e-04        0.233012
# 6  0.000273  0.000279  6.112266e-06        0.021875
# 7  0.840896  1.002500  1.616035e-01        0.161201
#
# Maximun value in Relative Error: 0.23301190491871915
# Mean value in Relative Error: 0.061417887556394365
#
# Result for h=1, i=3
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.004116  0.004116  9.979580e-08        0.000024
# 1  0.003749  0.003745  3.852200e-06        0.001029
# 2  0.001162  0.001162  5.620149e-08        0.000048
# 3  0.918629  0.920150  1.520548e-03        0.001653
# 4  0.001820  0.001754  6.580657e-05        0.037514
# 5  0.001862  0.001728  1.336005e-04        0.077311
# 6  0.000444  0.000378  6.583655e-05        0.174162
# 7  0.937043  1.014900  7.785667e-02        0.076714
#
# Maximun value in Relative Error: 0.17416156089657256
# Mean value in Relative Error: 0.04605665527153633
#
# Result for h=1, i=4
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.000585  0.000585  2.095550e-08        0.000036
# 1  0.000527  0.000526  4.100629e-07        0.000779
# 2  0.000445  0.000445  1.276351e-08        0.000029
# 3  0.870040  0.871370  1.330348e-03        0.001527
# 4  0.000208  0.000323  1.149902e-04        0.355875
# 5  0.000217  0.000333  1.153653e-04        0.346859
# 6  0.000124  0.000113  1.104963e-05        0.097422
# 7  0.928817  1.031600  1.027834e-01        0.099635
#
# Maximun value in Relative Error: 0.35587465260516216
# Mean value in Relative Error: 0.11277018766035592
#
# Result for h=2, i=1
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.004853  0.004853  5.693431e-08        0.000012
# 1  0.005115  0.005116  1.084138e-06        0.000212
# 2  0.001015  0.001015  3.954567e-08        0.000039
# 3  0.850239  0.851170  9.310278e-04        0.001094
# 4  0.003835  0.004392  5.576411e-04        0.126956
# 5  0.004138  0.005207  1.068622e-03        0.205232
# 6  0.000800  0.000698  1.018393e-04        0.145920
# 7  0.914637  1.014600  9.996293e-02        0.098524
#
# Maximun value in Relative Error: 0.20523195403562125
# Mean value in Relative Error: 0.07224865170143918
#
# Result for h=2, i=2
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.001372  0.001372  2.461153e-08    1.793713e-05
# 1  0.001478  0.001478  4.392949e-07    2.972226e-04
# 2  0.000371  0.000371  2.975005e-11    8.024288e-08
# 3  0.813075  0.814020  9.450823e-04    1.161006e-03
# 4  0.001496  0.001544  4.748559e-05    3.075890e-02
# 5  0.001630  0.002133  5.031517e-04    2.358339e-01
# 6  0.000371  0.000380  8.828456e-06    2.321628e-02
# 7  0.840896  1.002500  1.616035e-01    1.612005e-01
#
# Maximun value in Relative Error: 0.23583391292753264
# Mean value in Relative Error: 0.05656073362703023
#
# Result for h=2, i=3
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.008792  0.008792  2.445139e-07        0.000028
# 1  0.008379  0.008374  4.386959e-06        0.000524
# 2  0.001559  0.001559  4.801744e-08        0.000031
# 3  0.918629  0.920150  1.520548e-03        0.001653
# 4  0.003076  0.003555  4.783152e-04        0.134559
# 5  0.003187  0.003554  3.670474e-04        0.103286
# 6  0.000599  0.000508  9.117846e-05        0.179627
# 7  0.937043  1.014900  7.785667e-02        0.076714
#
# Maximun value in Relative Error: 0.17962660332138558
# Mean value in Relative Error: 0.06205246339883914
#
# Result for h=2, i=4
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.001078  0.001078  1.366097e-09        0.000001
# 1  0.001045  0.001045  2.276095e-07        0.000218
# 2  0.000606  0.000606  1.234112e-08        0.000020
# 3  0.870040  0.871370  1.330348e-03        0.001527
# 4  0.000409  0.000581  1.718167e-04        0.295675
# 5  0.000429  0.000643  2.144407e-04        0.333241
# 6  0.000169  0.000154  1.532997e-05        0.099817
# 7  0.928817  1.031600  1.027834e-01        0.099635
#
# Maximun value in Relative Error: 0.33324114714236425
# Mean value in Relative Error: 0.10376683321724665
#
# Result for h=3, i=1
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.006301  0.006300  1.538946e-07        0.000024
# 1  0.006661  0.006661  9.104094e-07        0.000137
# 2  0.001254  0.001254  4.092514e-09        0.000003
# 3  0.836861  0.837610  7.487950e-04        0.000894
# 4  0.005836  0.006237  4.008408e-04        0.064267
# 5  0.006155  0.007357  1.201778e-03        0.163360
# 6  0.000952  0.000842  1.095187e-04        0.130064
# 7  0.914146  1.015500  1.013536e-01        0.099807
#
# Maximun value in Relative Error: 0.1633604756453932
# Mean value in Relative Error: 0.0573195176612786
#
# Result for h=3, i=2
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.001644  0.001644  4.073458e-09        0.000002
# 1  0.001781  0.001781  3.042967e-07        0.000171
# 2  0.000455  0.000454  4.980156e-09        0.000011
# 3  0.798354  0.798920  5.658143e-04        0.000708
# 4  0.002352  0.002185  1.668073e-04        0.076345
# 5  0.002503  0.002867  3.637714e-04        0.126873
# 6  0.000442  0.000462  1.954552e-05        0.042322
# 7  0.867300  1.000500  1.331996e-01        0.133133
#
# Maximun value in Relative Error: 0.13313301141807765
# Mean value in Relative Error: 0.0474457848992668
#
# Result for h=3, i=3
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.013328  0.013328  3.110616e-07        0.000023
# 1  0.013002  0.012994  7.734713e-06        0.000595
# 2  0.001945  0.001945  5.913364e-09        0.000003
# 3  0.911829  0.914830  3.000672e-03        0.003280
# 4  0.004937  0.005130  1.928846e-04        0.037603
# 5  0.005110  0.005269  1.592201e-04        0.030219
# 6  0.000683  0.000607  7.565538e-05        0.124595
# 7  0.931970  1.017700  8.573017e-02        0.084239
#
# Maximun value in Relative Error: 0.12459508043306873
# Mean value in Relative Error: 0.03506971603362146
#
# Result for h=3, i=4
# -------------------
#
#      Actual  Expected         Error  Relative Error
# 0  0.001359  0.001359  1.115265e-07        0.000082
# 1  0.001341  0.001340  4.634694e-07        0.000346
# 2  0.000734  0.000734  1.443554e-08        0.000020
# 3  0.871394  0.873480  2.085537e-03        0.002388
# 4  0.000637  0.000866  2.287842e-04        0.264139
# 5  0.000652  0.000937  2.853068e-04        0.304525
# 6  0.000213  0.000183  3.006510e-05        0.164623
# 7  0.927735  1.032800  1.050649e-01        0.101728
#
# Maximun value in Relative Error: 0.30452535783367757
# Mean value in Relative Error: 0.10473138170082794
